# %% [markdown]
# # The Central Limit Theorem

# %% [raw]
# Let's start with the history of Central Limit Theorem.
# There are a lot of different versions of Central Limit Theorem, from approximately 1810 to 1935.
# The standard version of the theorem, first proved by the French mathematician Pierre- Simon Laplace in 1810. It states that the sum or average of an infinite sequence of independent and identically distributed random variables tends to normal distribution.

# %% [markdown]
# ## Normal Distribution

# %% [raw]
# Normal distribution is a probability distribution that is symmetric about the mean.
# Showing that data near the mean are more frequent in occurence than the data far from the mean
# # Let's see with a graph below

# %% [markdown]
# ## Normal Distribution Graph

# %%
# importing libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
#
# Create a normal distribution with mean as 10 and standard deviation as 8
#
mean_value = 5
std = 10
snd = stats.norm(mean_value, std)
#
# Generate 1000 random values between -100, 100
x = np.linspace(-100, 100, 1000)
#
# Plot the standard normal distribution for different values of random variable
# falling in the range -100, 100
#
plt.figure(figsize=(5, 5))
plt.plot(x, snd.pdf(x))
plt.xlim(-60, 60)
plt.title('Normal Distribution (Mean = 5, STD = 10)', fontsize='10')
plt.xlabel('Values of Random Variable X', fontsize='10')
plt.ylabel('Probability', fontsize='15')
plt.show()

# %% [markdown]
# The Central Limit Theorem states that the sampling distribution of the sample means approaches a normal distribution as the sample size gets larger — no matter what the shape of the population distribution. This fact holds especially true for sample sizes over 30.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### References

# %%
https://www.britannica.com/science/central-limit-theorem 
http://www.medicine.mcgill.ca/epidemiology/hanley/bios601/GaussianModel/HistoryCentralLimitTheorem.pdf 
https://www.investopedia.com/terms/n/normaldistribution.asp
https://www.statisticshowto.com/probability-and-statistics/normal-distributions/central-limit-theorem-definition-examples/
