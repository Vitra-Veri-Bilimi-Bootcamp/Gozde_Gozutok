# %% [markdown]
# # Statistical Terms: Variance, Covariance and Correlation

# %% [markdown]
# ![Statistically-Insignificant-5ebc0b543947d__880.jpg](attachment:Statistically-Insignificant-5ebc0b543947d__880.jpg)

# %% [markdown]
# You can find the article on this subject on Medium at the link below.

# %% [markdown]
# Link:https://medium.com/@gozdegozutok268/statistical-terms-variance-standard-deviation-covariance-and-correlation-f0b02c3275bc
